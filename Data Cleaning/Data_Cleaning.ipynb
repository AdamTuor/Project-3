# %%
import pandas as pd
data = pd.read_csv('../Resources/Auto_Theft_Open_Data.csv')
data2 = pd.read_csv('../Resources/Assault_Open_Data.csv')
data3 = pd.read_csv('../Resources/Bicycle_Thefts_Open_Data.csv')
data4 = pd.read_csv('../Resources/Break_and_Enter_Open_Data.csv')
data5 = pd.read_csv('../Resources/Homicides_Open_Data_ASR_RC_TBL_002.csv')
data6 = pd.read_csv('../Resources/Robbery_Open_Data.csv')
data7 = pd.read_csv('../Resources/Shooting_and_Firearm_Discharges_Open_Data.csv')
data8 = pd.read_csv('../Resources/Theft_From_Motor_Vehicle_Open_Data.csv')
data9 = pd.read_csv('../Resources/Theft_Over_Open_Data.csv')

# %% [markdown]
# ### Don't be broken

# %%
df = pd.DataFrame(data)
df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)
df4 = pd.DataFrame(data4)
df5 = pd.DataFrame(data5)
df6 = pd.DataFrame(data6)
df7 = pd.DataFrame(data7)
df8 = pd.DataFrame(data8)
df9 = pd.DataFrame(data9)

# %%
frames = [df,df2,df3,df4,df5,df6,df7,df8,df9]

# %%
result = pd.concat(frames)

# %%
result.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'EVENT_UNIQUE_ID', 'REPORT_DATE', 'OCC_DATE',
#        'REPORT_YEAR', 'REPORT_MONTH', 'REPORT_DAY', 'REPORT_DOY', 'REPORT_DOW',
#        'REPORT_HOUR', 'OCC_YEAR', 'OCC_MONTH', 'OCC_DAY', 'OCC_DOY', 'OCC_DOW',
#        'OCC_HOUR', 'DIVISION', 'LOCATION_TYPE', 'PREMISES_TYPE', 'UCR_CODE',
#        'UCR_EXT', 'OFFENCE', 'MCI_CATEGORY', 'HOOD_158', 'NEIGHBOURHOOD_158',
#        'HOOD_140', 'NEIGHBOURHOOD_140', 'LONG_WGS84', 'LAT_WGS84',
#        'PRIMARY_OFFENCE', 'BIKE_MAKE', 'BIKE_MODEL', 'BIKE_TYPE', 'BIKE_SPEED',
#        'BIKE_COLOUR', 'BIKE_COST', 'STATUS', 'HOMICIDE_TYPE', 'OCC_TIME_RANGE',
#        'DEATH', 'INJURIES', 'F_num_removed'],
#       dtype='object')

# %% [markdown]
# ### Auto Theft Data

# %%
columns_to_keep = ['X', 'Y','REPORT_YEAR', 'REPORT_MONTH','LOCATION_TYPE','OFFENCE','MCI_CATEGORY','HOOD_158', 'NEIGHBOURHOOD_158']

# %%
filtered_df = result[columns_to_keep]

# %%
filtered_df = filtered_df[filtered_df['HOOD_158'] != 'NSA']

# %%
filtered_df
# Out:
#                X          Y  REPORT_YEAR REPORT_MONTH  \
# 0     -79.306757  43.734652       2014.0      January
# 1     -79.236189  43.721847       2014.0      January
# 2     -79.529478  43.618472       2014.0      January
# 3     -79.516814  43.683438       2014.0      January
# 4     -79.595364  43.744281       2014.0      January
# ...          ...        ...          ...          ...
# 10740 -79.533497  43.733619       2022.0     December
# 10741 -79.391279  43.671127       2022.0     December
# 10742 -79.412053  43.763068       2022.0     December
# 10743 -79.418131  43.790247       2022.0     December
# 10744 -79.258766  43.773233       2022.0     December
#
#                                            LOCATION_TYPE  \
# 0                       Apartment (Rooming House, Condo)
# 1      Streets, Roads, Highways (Bicycle Path, Privat...
# 2      Parking Lots (Apt., Commercial Or Non-Commercial)
# 3      Parking Lots (Apt., Commercial Or Non-Commercial)
# 4      Parking Lots (Apt., Commercial Or Non-Commercial)
# ...                                                  ...
# 10740  Other Commercial / Corporate Places (For Profi...
# 10741  Parking Lots (Apt., Commercial Or Non-Commercial)
# 10742  Parking Lots (Apt., Commercial Or Non-Commercial)
# 10743                   Apartment (Rooming House, Condo)
# 10744                   Apartment (Rooming House, Condo)
#
#                              OFFENCE MCI_CATEGORY HOOD_158  \
# 0             Theft Of Motor Vehicle   Auto Theft       43
# 1             Theft Of Motor Vehicle   Auto Theft      123
# 2             Theft Of Motor Vehicle   Auto Theft      159
# 3             Theft Of Motor Vehicle   Auto Theft        9
# 4             Theft Of Motor Vehicle   Auto Theft        2
# ...                              ...          ...      ...
# 10740                     Theft Over   Theft Over       23
# 10741  Theft From Motor Vehicle Over   Theft Over       95
# 10742  Theft From Motor Vehicle Over   Theft Over       38
# 10743  Theft From Motor Vehicle Over   Theft Over       50
# 10744                     Theft Over   Theft Over      156
#
#                        NEIGHBOURHOOD_158
# 0                       Victoria Village
# 1                             Cliffcrest
# 2                  Etobicoke City Centre
# 3               Edenbridge-Humber Valley
# 4      Mount Olive-Silverstone-Jamestown
# ...                                  ...
# 10740               Pelmo Park-Humberlea
# 10741                              Annex
# 10742                   Lansing-Westgate
# 10743                   Newtonbrook East
# 10744                Bendale-Glen Andrew
#
# [437303 rows x 9 columns]

# %%
filtered_df.to_csv('../Resources/Final_Dataset.csv')
